# %% [markdown]
# # Importing the required libraries

# %%
import sys
from matplotlib import pyplot as plt
from tensorflow.keras.datasets import fashion_mnist,mnist,cifar10
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout,Flatten,Dense,MaxPooling2D,Conv2D
from tensorflow.keras.optimizers import SGD
import time
import numpy as np
import warnings
warnings.filterwarnings("ignore")

epochs = 100

# %% [markdown]
# # CNN Cifar 10

# %%
# load train and test dataset
def load_dataset():
	# load dataset
	(trainX, trainY), (testX, testY) = cifar10.load_data()
	# one hot encode target values
	trainY = to_categorical(trainY)
	testY = to_categorical(testY)
	return trainX, trainY, testX, testY
 
# scale pixels
def prep_pixels(train, test):
	# convert from integers to floats
	train_norm = train.astype('float32')
	test_norm = test.astype('float32')
	# normalize to range 0-1
	train_norm = train_norm / 255.0
	test_norm = test_norm / 255.0
	# return normalized images
	return train_norm, test_norm
 
# define cnn model
def define_model():
	model = Sequential()
	model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(32, 32, 3)))
	model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(MaxPooling2D((2, 2)))
	model.add(Dropout(0.2))
	model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(MaxPooling2D((2, 2)))
	model.add(Dropout(0.2))
	model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(MaxPooling2D((2, 2)))
	model.add(Dropout(0.2))
	model.add(Flatten())
	model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
	model.add(Dropout(0.2))
	model.add(Dense(10, activation='softmax'))
	# compile model
	opt = SGD(learning_rate=0.001, momentum=0.9)
	model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
	return model
 
# plot diagnostic learning curves
def summarize_diagnostics(history):
	acc = history.history['accuracy']
	val_acc = history.history['val_accuracy']
	epochs_range = range(epochs)

	plt.figure(figsize=(8, 8))
	plt.plot(epochs_range, acc, label='Training Accuracy',c='g')
	plt.plot(epochs_range, val_acc, label='Validation Accuracy',c='y')
	plt.legend(loc='lower right')
	plt.title('Training and Validation Accuracy')
	plt.xlabel('Epochs')
	plt.ylabel('Accuracy')
	plt.show()

def Loss_Diagnostics(history):
	loss = history.history['loss']
	val_loss = history.history['val_loss']
	epochs_range = range(epochs)
 
	plt.figure(figsize=(8, 8))	
	plt.plot(epochs_range, loss, label='Training Loss',c='g')
	plt.plot(epochs_range, val_loss, label='Validation Loss',c='y')
	plt.legend(loc='upper right')
	plt.title('Training and Validation Loss')
	plt.xlabel('Epochs')
	plt.ylabel('Accuracy')
	plt.show()
 
# run the test harness for evaluating a model
def run_test_harness():
	# load dataset
	trainX, trainY, testX, testY = load_dataset()
	# prepare pixel data
	trainX, testX = prep_pixels(trainX, testX)
	# define model
	model = define_model()
	# fit model
	history = model.fit(trainX, trainY, epochs=epochs, batch_size=64, validation_data=(testX, testY), verbose=1)
	# evaluate model
	val, acc = model.evaluate(testX, testY, verbose=1)
	print('')
	print('Model Test Accuracy: ', acc*100, " %")
    
	# learning curves
	print('Output Graphs: \n')
	summarize_diagnostics(history)
	Loss_Diagnostics(history)
 

#Running Time Calculation
start_Cifar = time.time()
run_test_harness()
end_Cifar = time.time()
time_Cifar = end_Cifar - start_Cifar
print("Program Execution Time (GPU): ", time_Cifar , " seconds")
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 4s 0us/step
# 170508288/170498071 [==============================] - 4s 0us/step
# Epoch 1/100
# 782/782 [==============================] - 16s 7ms/step - loss: 2.0133 - accuracy: 0.2514 - val_loss: 1.6630 - val_accuracy: 0.3963
# Epoch 2/100
# 782/782 [==============================] - 5s 7ms/step - loss: 1.6683 - accuracy: 0.3855 - val_loss: 1.5236 - val_accuracy: 0.4530
# Epoch 3/100
# 782/782 [==============================] - 5s 7ms/step - loss: 1.5208 - accuracy: 0.4391 - val_loss: 1.3733 - val_accuracy: 0.5049
# Epoch 4/100
# 782/782 [==============================] - 5s 7ms/step - loss: 1.4206 - accuracy: 0.4798 - val_loss: 1.3180 - val_accuracy: 0.5239
# Epoch 5/100
# 782/782 [==============================] - 5s 7ms/step - loss: 1.3536 - accuracy: 0.5085 - val_loss: 1.2181 - val_accuracy: 0.5643
# Epoch 6/100
# 782/782 [==============================] - 5s 7ms/step - loss: 1.2911 - accuracy: 0.5306 - val_loss: 1.1962 - val_accuracy: 0.5767
# Epoch 7/100
# 782/782 [==============================] - 5s 7ms/step - loss: 1.2361 - accuracy: 0.5568 - val_loss: 1.1764 - val_accuracy: 0.5883
# Epoch 8/100
# 782/782 [==============================] - 5s 7ms/step - loss: 1.1830 - accuracy: 0.5758 - val_loss: 1.0612 - val_accuracy: 0.6259
# Epoch 9/100
# 782/782 [==============================] - 5s 7ms/step - loss: 1.1372 - accuracy: 0.5932 - val_loss: 1.1079 - val_accuracy: 0.6129
# Epoch 10/100
# 782/782 [==============================] - 5s 7ms/step - loss: 1.0922 - accuracy: 0.6079 - val_loss: 0.9911 - val_accuracy: 0.6528
# Epoch 11/100
# 782/782 [==============================] - 5s 7ms/step - loss: 1.0507 - accuracy: 0.6256 - val_loss: 0.9718 - val_accuracy: 0.6594
# Epoch 12/100
# 782/782 [==============================] - 5s 7ms/step - loss: 1.0157 - accuracy: 0.6397 - val_loss: 0.9391 - val_accuracy: 0.6715
# Epoch 13/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.9790 - accuracy: 0.6527 - val_loss: 0.9090 - val_accuracy: 0.6803
# Epoch 14/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.9483 - accuracy: 0.6640 - val_loss: 0.8986 - val_accuracy: 0.6811
# Epoch 15/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.9160 - accuracy: 0.6777 - val_loss: 0.8385 - val_accuracy: 0.7070
# Epoch 16/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.8851 - accuracy: 0.6865 - val_loss: 0.8681 - val_accuracy: 0.7020
# Epoch 17/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.8639 - accuracy: 0.6966 - val_loss: 0.8175 - val_accuracy: 0.7162
# Epoch 18/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.8416 - accuracy: 0.7046 - val_loss: 0.7743 - val_accuracy: 0.7257
# Epoch 19/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.8166 - accuracy: 0.7112 - val_loss: 0.7599 - val_accuracy: 0.7388
# Epoch 20/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.7974 - accuracy: 0.7193 - val_loss: 0.7311 - val_accuracy: 0.7429
# Epoch 21/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.7764 - accuracy: 0.7262 - val_loss: 0.7397 - val_accuracy: 0.7410
# Epoch 22/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.7669 - accuracy: 0.7305 - val_loss: 0.7216 - val_accuracy: 0.7486
# Epoch 23/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.7472 - accuracy: 0.7376 - val_loss: 0.7143 - val_accuracy: 0.7456
# Epoch 24/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.7278 - accuracy: 0.7446 - val_loss: 0.7132 - val_accuracy: 0.7509
# Epoch 25/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.7167 - accuracy: 0.7467 - val_loss: 0.6898 - val_accuracy: 0.7596
# Epoch 26/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.6960 - accuracy: 0.7554 - val_loss: 0.6743 - val_accuracy: 0.7648
# Epoch 27/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.6831 - accuracy: 0.7605 - val_loss: 0.6772 - val_accuracy: 0.7670
# Epoch 28/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.6700 - accuracy: 0.7639 - val_loss: 0.6550 - val_accuracy: 0.7737
# Epoch 29/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.6631 - accuracy: 0.7674 - val_loss: 0.6544 - val_accuracy: 0.7761
# Epoch 30/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.6472 - accuracy: 0.7722 - val_loss: 0.6455 - val_accuracy: 0.7722
# Epoch 31/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.6314 - accuracy: 0.7778 - val_loss: 0.6220 - val_accuracy: 0.7839
# Epoch 32/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.6202 - accuracy: 0.7825 - val_loss: 0.6309 - val_accuracy: 0.7823
# Epoch 33/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.6188 - accuracy: 0.7833 - val_loss: 0.6537 - val_accuracy: 0.7765
# Epoch 34/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.6052 - accuracy: 0.7871 - val_loss: 0.6177 - val_accuracy: 0.7871
# Epoch 35/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.5932 - accuracy: 0.7921 - val_loss: 0.6304 - val_accuracy: 0.7836
# Epoch 36/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.5845 - accuracy: 0.7933 - val_loss: 0.6142 - val_accuracy: 0.7891
# Epoch 37/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.5741 - accuracy: 0.7970 - val_loss: 0.5998 - val_accuracy: 0.7915
# Epoch 38/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.5690 - accuracy: 0.7993 - val_loss: 0.6050 - val_accuracy: 0.7924
# Epoch 39/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.5551 - accuracy: 0.8050 - val_loss: 0.5953 - val_accuracy: 0.7984
# Epoch 40/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.5479 - accuracy: 0.8080 - val_loss: 0.5956 - val_accuracy: 0.7943
# Epoch 41/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.5373 - accuracy: 0.8096 - val_loss: 0.5838 - val_accuracy: 0.8036
# Epoch 42/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.5317 - accuracy: 0.8107 - val_loss: 0.6020 - val_accuracy: 0.7917
# Epoch 43/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.5253 - accuracy: 0.8149 - val_loss: 0.5771 - val_accuracy: 0.8007
# Epoch 44/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.5132 - accuracy: 0.8189 - val_loss: 0.5714 - val_accuracy: 0.8035
# Epoch 45/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.5066 - accuracy: 0.8204 - val_loss: 0.5816 - val_accuracy: 0.8001
# Epoch 46/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.4994 - accuracy: 0.8230 - val_loss: 0.5809 - val_accuracy: 0.8038
# Epoch 47/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.4926 - accuracy: 0.8249 - val_loss: 0.5647 - val_accuracy: 0.8088
# Epoch 48/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.4855 - accuracy: 0.8244 - val_loss: 0.5637 - val_accuracy: 0.8106
# Epoch 49/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.4791 - accuracy: 0.8295 - val_loss: 0.5688 - val_accuracy: 0.8091
# Epoch 50/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.4759 - accuracy: 0.8308 - val_loss: 0.5710 - val_accuracy: 0.8102
# Epoch 51/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.4622 - accuracy: 0.8349 - val_loss: 0.5462 - val_accuracy: 0.8139
# Epoch 52/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.4563 - accuracy: 0.8377 - val_loss: 0.5618 - val_accuracy: 0.8092
# Epoch 53/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.4514 - accuracy: 0.8386 - val_loss: 0.5666 - val_accuracy: 0.8121
# Epoch 54/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.4432 - accuracy: 0.8413 - val_loss: 0.5619 - val_accuracy: 0.8092
# Epoch 55/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.4368 - accuracy: 0.8447 - val_loss: 0.5715 - val_accuracy: 0.8076
# Epoch 56/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.4321 - accuracy: 0.8467 - val_loss: 0.5650 - val_accuracy: 0.8123
# Epoch 57/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.4242 - accuracy: 0.8488 - val_loss: 0.5792 - val_accuracy: 0.8096
# Epoch 58/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.4211 - accuracy: 0.8504 - val_loss: 0.5738 - val_accuracy: 0.8106
# Epoch 59/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.4135 - accuracy: 0.8532 - val_loss: 0.5650 - val_accuracy: 0.8119
# Epoch 60/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.4036 - accuracy: 0.8557 - val_loss: 0.5373 - val_accuracy: 0.8197
# Epoch 61/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.4008 - accuracy: 0.8579 - val_loss: 0.5569 - val_accuracy: 0.8139
# Epoch 62/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.3987 - accuracy: 0.8573 - val_loss: 0.5392 - val_accuracy: 0.8227
# Epoch 63/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.3910 - accuracy: 0.8614 - val_loss: 0.5573 - val_accuracy: 0.8154
# Epoch 64/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.3895 - accuracy: 0.8601 - val_loss: 0.5738 - val_accuracy: 0.8102
# Epoch 65/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.3799 - accuracy: 0.8633 - val_loss: 0.5569 - val_accuracy: 0.8203
# Epoch 66/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.3784 - accuracy: 0.8659 - val_loss: 0.5498 - val_accuracy: 0.8186
# Epoch 67/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.3693 - accuracy: 0.8671 - val_loss: 0.5586 - val_accuracy: 0.8165
# Epoch 68/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.3649 - accuracy: 0.8677 - val_loss: 0.5446 - val_accuracy: 0.8223
# Epoch 69/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.3596 - accuracy: 0.8715 - val_loss: 0.5452 - val_accuracy: 0.8215
# Epoch 70/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.3601 - accuracy: 0.8708 - val_loss: 0.5421 - val_accuracy: 0.8261
# Epoch 71/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.3572 - accuracy: 0.8722 - val_loss: 0.5650 - val_accuracy: 0.8193
# Epoch 72/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.3445 - accuracy: 0.8767 - val_loss: 0.5667 - val_accuracy: 0.8215
# Epoch 73/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.3378 - accuracy: 0.8802 - val_loss: 0.5687 - val_accuracy: 0.8168
# Epoch 74/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.3347 - accuracy: 0.8795 - val_loss: 0.5628 - val_accuracy: 0.8216
# Epoch 75/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.3354 - accuracy: 0.8789 - val_loss: 0.5419 - val_accuracy: 0.8252
# Epoch 76/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.3281 - accuracy: 0.8825 - val_loss: 0.5479 - val_accuracy: 0.8259
# Epoch 77/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.3235 - accuracy: 0.8849 - val_loss: 0.5555 - val_accuracy: 0.8268
# Epoch 78/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.3207 - accuracy: 0.8836 - val_loss: 0.5516 - val_accuracy: 0.8225
# Epoch 79/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.3195 - accuracy: 0.8853 - val_loss: 0.5818 - val_accuracy: 0.8186
# Epoch 80/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.3112 - accuracy: 0.8875 - val_loss: 0.5503 - val_accuracy: 0.8272
# Epoch 81/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.3046 - accuracy: 0.8905 - val_loss: 0.5612 - val_accuracy: 0.8261
# Epoch 82/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.3036 - accuracy: 0.8901 - val_loss: 0.5555 - val_accuracy: 0.8255
# Epoch 83/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.3018 - accuracy: 0.8910 - val_loss: 0.5477 - val_accuracy: 0.8300
# Epoch 84/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.3000 - accuracy: 0.8929 - val_loss: 0.5512 - val_accuracy: 0.8262
# Epoch 85/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.2913 - accuracy: 0.8946 - val_loss: 0.5627 - val_accuracy: 0.8233
# Epoch 86/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.2860 - accuracy: 0.8965 - val_loss: 0.5579 - val_accuracy: 0.8294
# Epoch 87/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.2856 - accuracy: 0.8975 - val_loss: 0.5751 - val_accuracy: 0.8256
# Epoch 88/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.2848 - accuracy: 0.8983 - val_loss: 0.5778 - val_accuracy: 0.8234
# Epoch 89/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.2763 - accuracy: 0.8990 - val_loss: 0.5639 - val_accuracy: 0.8286
# Epoch 90/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.2743 - accuracy: 0.9003 - val_loss: 0.5688 - val_accuracy: 0.8286
# Epoch 91/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.2701 - accuracy: 0.9032 - val_loss: 0.5567 - val_accuracy: 0.8263
# Epoch 92/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.2688 - accuracy: 0.9028 - val_loss: 0.5713 - val_accuracy: 0.8243
# Epoch 93/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.2695 - accuracy: 0.9028 - val_loss: 0.5627 - val_accuracy: 0.8341
# Epoch 94/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.2566 - accuracy: 0.9075 - val_loss: 0.5653 - val_accuracy: 0.8322
# Epoch 95/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.2559 - accuracy: 0.9082 - val_loss: 0.5843 - val_accuracy: 0.8280
# Epoch 96/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.2541 - accuracy: 0.9077 - val_loss: 0.5714 - val_accuracy: 0.8283
# Epoch 97/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.2494 - accuracy: 0.9108 - val_loss: 0.5915 - val_accuracy: 0.8248
# Epoch 98/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.2499 - accuracy: 0.9090 - val_loss: 0.5728 - val_accuracy: 0.8318
# Epoch 99/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.2422 - accuracy: 0.9113 - val_loss: 0.5794 - val_accuracy: 0.8299
# Epoch 100/100
# 782/782 [==============================] - 5s 7ms/step - loss: 0.2443 - accuracy: 0.9116 - val_loss: 0.5743 - val_accuracy: 0.8299
# 313/313 [==============================] - 1s 3ms/step - loss: 0.5743 - accuracy: 0.8299
#
# Model Test Accuracy:  82.99000263214111  %
# Output Graphs:
# Program Execution Time (GPU):  545.7492320537567  seconds

# %% [markdown]
# # CNN Fashion

# %%
# load train and test dataset
(trainX, trainY), (testX, testY) = fashion_mnist.load_data()
trainY = to_categorical(trainY)
testY = to_categorical(testY)

# convert from integers to floats
train_norm = trainX.astype('float32')
test_norm = testX.astype('float32')

# normalize to range 0-1
train_norm = train_norm / 255.0
test_norm = test_norm / 255.0
# return normalized images

trainX = np.expand_dims(train_norm, -1)
testX = np.expand_dims(test_norm, -1)
 
# define cnn model
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(28, 28,1)))
model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.2))
model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.2))
model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax'))
# compile model
model.compile(optimizer="adam", loss='categorical_crossentropy', metrics=['accuracy'])

start_fashion = time.time()
# fit model
history = model.fit(trainX, trainY, epochs=epochs, batch_size=100, validation_data=(testX, testY), verbose=1)
val, acc = model.evaluate(testX, testY, verbose=1)
print('')
print('Model Test Accuracy: ', acc*100, " %")
end_fashion = time.time()
time_fashion = end_fashion - start_fashion
print("Program Execution Time (GPU): ", time_fashion , " seconds")


# plot diagnostic learning curves
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.plot(epochs_range, acc, label='Training Accuracy',c='g')
plt.plot(epochs_range, val_acc, label='Validation Accuracy',c='y')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show()

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))	
plt.plot(epochs_range, loss, label='Training Loss',c='g')
plt.plot(epochs_range, val_loss, label='Validation Loss',c='y')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# 26435584/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step
# Epoch 1/100
# 600/600 [==============================] - 5s 8ms/step - loss: 0.6037 - accuracy: 0.7829 - val_loss: 0.3456 - val_accuracy: 0.8738
# Epoch 2/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.3287 - accuracy: 0.8798 - val_loss: 0.2947 - val_accuracy: 0.8910
# Epoch 3/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.2765 - accuracy: 0.9003 - val_loss: 0.2547 - val_accuracy: 0.9072
# Epoch 4/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.2472 - accuracy: 0.9098 - val_loss: 0.2461 - val_accuracy: 0.9079
# Epoch 5/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.2239 - accuracy: 0.9173 - val_loss: 0.2434 - val_accuracy: 0.9094
# Epoch 6/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.2099 - accuracy: 0.9216 - val_loss: 0.2108 - val_accuracy: 0.9220
# Epoch 7/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.1976 - accuracy: 0.9281 - val_loss: 0.2085 - val_accuracy: 0.9225
# Epoch 8/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.1879 - accuracy: 0.9311 - val_loss: 0.2179 - val_accuracy: 0.9198
# Epoch 9/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.1784 - accuracy: 0.9341 - val_loss: 0.2086 - val_accuracy: 0.9292
# Epoch 10/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.1749 - accuracy: 0.9346 - val_loss: 0.2077 - val_accuracy: 0.9249
# Epoch 11/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.1653 - accuracy: 0.9387 - val_loss: 0.2009 - val_accuracy: 0.9303
# Epoch 12/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.1559 - accuracy: 0.9414 - val_loss: 0.2088 - val_accuracy: 0.9288
# Epoch 13/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.1519 - accuracy: 0.9432 - val_loss: 0.2110 - val_accuracy: 0.9259
# Epoch 14/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.1477 - accuracy: 0.9444 - val_loss: 0.2069 - val_accuracy: 0.9314
# Epoch 15/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.1406 - accuracy: 0.9470 - val_loss: 0.2025 - val_accuracy: 0.9313
# Epoch 16/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.1379 - accuracy: 0.9473 - val_loss: 0.1960 - val_accuracy: 0.9351
# Epoch 17/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.1325 - accuracy: 0.9509 - val_loss: 0.2017 - val_accuracy: 0.9344
# Epoch 18/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.1286 - accuracy: 0.9526 - val_loss: 0.2066 - val_accuracy: 0.9336
# Epoch 19/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.1294 - accuracy: 0.9526 - val_loss: 0.2050 - val_accuracy: 0.9327
# Epoch 20/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.1216 - accuracy: 0.9549 - val_loss: 0.2171 - val_accuracy: 0.9329
# Epoch 21/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.1208 - accuracy: 0.9532 - val_loss: 0.2069 - val_accuracy: 0.9317
# Epoch 22/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.1178 - accuracy: 0.9568 - val_loss: 0.2341 - val_accuracy: 0.9323
# Epoch 23/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.1157 - accuracy: 0.9568 - val_loss: 0.2148 - val_accuracy: 0.9341
# Epoch 24/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.1129 - accuracy: 0.9581 - val_loss: 0.2264 - val_accuracy: 0.9335
# Epoch 25/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.1113 - accuracy: 0.9579 - val_loss: 0.2299 - val_accuracy: 0.9307
# Epoch 26/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.1100 - accuracy: 0.9596 - val_loss: 0.2134 - val_accuracy: 0.9358
# Epoch 27/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.1066 - accuracy: 0.9605 - val_loss: 0.2328 - val_accuracy: 0.9350
# Epoch 28/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.1061 - accuracy: 0.9603 - val_loss: 0.2375 - val_accuracy: 0.9319
# Epoch 29/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.1034 - accuracy: 0.9617 - val_loss: 0.2310 - val_accuracy: 0.9353
# Epoch 30/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.1026 - accuracy: 0.9617 - val_loss: 0.2356 - val_accuracy: 0.9340
# Epoch 31/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.1026 - accuracy: 0.9620 - val_loss: 0.2574 - val_accuracy: 0.9299
# Epoch 32/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0987 - accuracy: 0.9631 - val_loss: 0.2549 - val_accuracy: 0.9330
# Epoch 33/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0990 - accuracy: 0.9628 - val_loss: 0.2442 - val_accuracy: 0.9332
# Epoch 34/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0949 - accuracy: 0.9646 - val_loss: 0.2444 - val_accuracy: 0.9337
# Epoch 35/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0968 - accuracy: 0.9639 - val_loss: 0.2637 - val_accuracy: 0.9303
# Epoch 36/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0924 - accuracy: 0.9658 - val_loss: 0.2447 - val_accuracy: 0.9351
# Epoch 37/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0964 - accuracy: 0.9647 - val_loss: 0.2370 - val_accuracy: 0.9330
# Epoch 38/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0924 - accuracy: 0.9649 - val_loss: 0.2556 - val_accuracy: 0.9320
# Epoch 39/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0917 - accuracy: 0.9657 - val_loss: 0.2465 - val_accuracy: 0.9366
# Epoch 40/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0907 - accuracy: 0.9658 - val_loss: 0.2645 - val_accuracy: 0.9305
# Epoch 41/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0885 - accuracy: 0.9675 - val_loss: 0.2479 - val_accuracy: 0.9336
# Epoch 42/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0861 - accuracy: 0.9683 - val_loss: 0.2692 - val_accuracy: 0.9336
# Epoch 43/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0918 - accuracy: 0.9661 - val_loss: 0.2409 - val_accuracy: 0.9352
# Epoch 44/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0840 - accuracy: 0.9686 - val_loss: 0.2658 - val_accuracy: 0.9342
# Epoch 45/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0853 - accuracy: 0.9687 - val_loss: 0.2652 - val_accuracy: 0.9337
# Epoch 46/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0884 - accuracy: 0.9682 - val_loss: 0.2545 - val_accuracy: 0.9333
# Epoch 47/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0867 - accuracy: 0.9681 - val_loss: 0.2568 - val_accuracy: 0.9347
# Epoch 48/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0849 - accuracy: 0.9690 - val_loss: 0.2537 - val_accuracy: 0.9370
# Epoch 49/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0823 - accuracy: 0.9698 - val_loss: 0.2585 - val_accuracy: 0.9350
# Epoch 50/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0837 - accuracy: 0.9689 - val_loss: 0.2776 - val_accuracy: 0.9359
# Epoch 51/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0805 - accuracy: 0.9711 - val_loss: 0.2603 - val_accuracy: 0.9359
# Epoch 52/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0834 - accuracy: 0.9697 - val_loss: 0.2646 - val_accuracy: 0.9342
# Epoch 53/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0808 - accuracy: 0.9700 - val_loss: 0.3024 - val_accuracy: 0.9321
# Epoch 54/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0799 - accuracy: 0.9700 - val_loss: 0.3057 - val_accuracy: 0.9307
# Epoch 55/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0784 - accuracy: 0.9713 - val_loss: 0.2849 - val_accuracy: 0.9345
# Epoch 56/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0789 - accuracy: 0.9716 - val_loss: 0.2852 - val_accuracy: 0.9325
# Epoch 57/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0797 - accuracy: 0.9704 - val_loss: 0.3137 - val_accuracy: 0.9354
# Epoch 58/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0746 - accuracy: 0.9731 - val_loss: 0.3087 - val_accuracy: 0.9327
# Epoch 59/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0761 - accuracy: 0.9725 - val_loss: 0.2785 - val_accuracy: 0.9310
# Epoch 60/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0789 - accuracy: 0.9705 - val_loss: 0.2965 - val_accuracy: 0.9323
# Epoch 61/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0740 - accuracy: 0.9728 - val_loss: 0.2826 - val_accuracy: 0.9349
# Epoch 62/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0784 - accuracy: 0.9723 - val_loss: 0.2898 - val_accuracy: 0.9339
# Epoch 63/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0799 - accuracy: 0.9713 - val_loss: 0.3048 - val_accuracy: 0.9348
# Epoch 64/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0744 - accuracy: 0.9735 - val_loss: 0.2813 - val_accuracy: 0.9370
# Epoch 65/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0748 - accuracy: 0.9732 - val_loss: 0.2939 - val_accuracy: 0.9343
# Epoch 66/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0764 - accuracy: 0.9721 - val_loss: 0.2802 - val_accuracy: 0.9357
# Epoch 67/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0754 - accuracy: 0.9733 - val_loss: 0.3106 - val_accuracy: 0.9340
# Epoch 68/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0766 - accuracy: 0.9729 - val_loss: 0.3067 - val_accuracy: 0.9375
# Epoch 69/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0713 - accuracy: 0.9748 - val_loss: 0.3211 - val_accuracy: 0.9320
# Epoch 70/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0759 - accuracy: 0.9730 - val_loss: 0.2713 - val_accuracy: 0.9347
# Epoch 71/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0728 - accuracy: 0.9736 - val_loss: 0.2926 - val_accuracy: 0.9325
# Epoch 72/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0772 - accuracy: 0.9728 - val_loss: 0.2858 - val_accuracy: 0.9329
# Epoch 73/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0749 - accuracy: 0.9731 - val_loss: 0.3109 - val_accuracy: 0.9324
# Epoch 74/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0704 - accuracy: 0.9738 - val_loss: 0.3182 - val_accuracy: 0.9332
# Epoch 75/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0775 - accuracy: 0.9726 - val_loss: 0.3156 - val_accuracy: 0.9336
# Epoch 76/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0712 - accuracy: 0.9751 - val_loss: 0.3138 - val_accuracy: 0.9365
# Epoch 77/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0722 - accuracy: 0.9747 - val_loss: 0.3093 - val_accuracy: 0.9339
# Epoch 78/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0679 - accuracy: 0.9754 - val_loss: 0.2955 - val_accuracy: 0.9328
# Epoch 79/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0762 - accuracy: 0.9732 - val_loss: 0.3293 - val_accuracy: 0.9341
# Epoch 80/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0695 - accuracy: 0.9752 - val_loss: 0.2920 - val_accuracy: 0.9346
# Epoch 81/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0699 - accuracy: 0.9755 - val_loss: 0.3112 - val_accuracy: 0.9342
# Epoch 82/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0749 - accuracy: 0.9730 - val_loss: 0.3129 - val_accuracy: 0.9344
# Epoch 83/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0715 - accuracy: 0.9746 - val_loss: 0.3194 - val_accuracy: 0.9370
# Epoch 84/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0733 - accuracy: 0.9742 - val_loss: 0.3122 - val_accuracy: 0.9363
# Epoch 85/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0724 - accuracy: 0.9745 - val_loss: 0.3134 - val_accuracy: 0.9377
# Epoch 86/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0726 - accuracy: 0.9746 - val_loss: 0.3281 - val_accuracy: 0.9336
# Epoch 87/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0731 - accuracy: 0.9749 - val_loss: 0.3109 - val_accuracy: 0.9371
# Epoch 88/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0726 - accuracy: 0.9750 - val_loss: 0.3080 - val_accuracy: 0.9361
# Epoch 89/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0660 - accuracy: 0.9766 - val_loss: 0.3243 - val_accuracy: 0.9346
# Epoch 90/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0675 - accuracy: 0.9755 - val_loss: 0.3121 - val_accuracy: 0.9357
# Epoch 91/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0691 - accuracy: 0.9760 - val_loss: 0.3119 - val_accuracy: 0.9349
# Epoch 92/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0691 - accuracy: 0.9768 - val_loss: 0.3260 - val_accuracy: 0.9335
# Epoch 93/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0716 - accuracy: 0.9750 - val_loss: 0.3385 - val_accuracy: 0.9336
# Epoch 94/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0777 - accuracy: 0.9728 - val_loss: 0.3279 - val_accuracy: 0.9316
# Epoch 95/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0654 - accuracy: 0.9764 - val_loss: 0.3816 - val_accuracy: 0.9334
# Epoch 96/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0668 - accuracy: 0.9770 - val_loss: 0.3447 - val_accuracy: 0.9379
# Epoch 97/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0622 - accuracy: 0.9784 - val_loss: 0.3379 - val_accuracy: 0.9361
# Epoch 98/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0678 - accuracy: 0.9773 - val_loss: 0.3329 - val_accuracy: 0.9336
# Epoch 99/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0678 - accuracy: 0.9766 - val_loss: 0.3520 - val_accuracy: 0.9355
# Epoch 100/100
# 600/600 [==============================] - 4s 7ms/step - loss: 0.0708 - accuracy: 0.9757 - val_loss: 0.3345 - val_accuracy: 0.9362
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3345 - accuracy: 0.9362
#
# Model Test Accuracy:  93.62000226974487  %
# Program Execution Time (GPU):  436.3112635612488  seconds

# %% [markdown]
# # CNN Mnist

# %%
# load train and test dataset
(trainX, trainY), (testX, testY) = mnist.load_data()
# one hot encode target values
trainY = to_categorical(trainY)
testY = to_categorical(testY)

# convert from integers to floats
train_norm = trainX.astype('float32')
test_norm = testX.astype('float32')

# normalize to range 0-1
train_norm = train_norm / 255.0
test_norm = test_norm / 255.0
# return normalized images

trainX = np.expand_dims(train_norm, -1)
testX = np.expand_dims(test_norm, -1) 

# define cnn model
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(28, 28,1)))
model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.2))
model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.2))
model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax'))
# compile model
model.compile(optimizer="adam", loss='categorical_crossentropy', metrics=['accuracy'])

 
# fit model
start_minst = time.time()
history = model.fit(trainX, trainY, epochs=epochs, batch_size=128, validation_data=(testX, testY), verbose=2)

val, acc = model.evaluate(testX, testY, verbose=1)
print('')
print('Model Test Accuracy: ', acc*100, " %")
end_mnist = time.time()
mnist_time = end_mnist - start_minst
print("Program Execution Time (GPU): ", mnist_time , " seconds")

# plot diagnostic learning curves
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.plot(epochs_range, acc, label='Training Accuracy',c='g')
plt.plot(epochs_range, val_acc, label='Validation Accuracy',c='y')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show()

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))	
plt.plot(epochs_range, loss, label='Training Loss',c='g')
plt.plot(epochs_range, val_loss, label='Validation Loss',c='y')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step
# Epoch 1/100
# 469/469 - 5s - loss: 0.3542 - accuracy: 0.8845 - val_loss: 0.0517 - val_accuracy: 0.9827 - 5s/epoch - 10ms/step
# Epoch 2/100
# 469/469 - 4s - loss: 0.0690 - accuracy: 0.9788 - val_loss: 0.0274 - val_accuracy: 0.9911 - 4s/epoch - 8ms/step
# Epoch 3/100
# 469/469 - 4s - loss: 0.0490 - accuracy: 0.9850 - val_loss: 0.0240 - val_accuracy: 0.9924 - 4s/epoch - 8ms/step
# Epoch 4/100
# 469/469 - 4s - loss: 0.0408 - accuracy: 0.9876 - val_loss: 0.0211 - val_accuracy: 0.9932 - 4s/epoch - 8ms/step
# Epoch 5/100
# 469/469 - 4s - loss: 0.0345 - accuracy: 0.9893 - val_loss: 0.0227 - val_accuracy: 0.9934 - 4s/epoch - 8ms/step
# Epoch 6/100
# 469/469 - 4s - loss: 0.0288 - accuracy: 0.9909 - val_loss: 0.0189 - val_accuracy: 0.9938 - 4s/epoch - 8ms/step
# Epoch 7/100
# 469/469 - 4s - loss: 0.0281 - accuracy: 0.9913 - val_loss: 0.0179 - val_accuracy: 0.9944 - 4s/epoch - 8ms/step
# Epoch 8/100
# 469/469 - 4s - loss: 0.0247 - accuracy: 0.9922 - val_loss: 0.0190 - val_accuracy: 0.9939 - 4s/epoch - 8ms/step
# Epoch 9/100
# 469/469 - 4s - loss: 0.0219 - accuracy: 0.9931 - val_loss: 0.0177 - val_accuracy: 0.9949 - 4s/epoch - 8ms/step
# Epoch 10/100
# 469/469 - 4s - loss: 0.0211 - accuracy: 0.9934 - val_loss: 0.0197 - val_accuracy: 0.9945 - 4s/epoch - 8ms/step
# Epoch 11/100
# 469/469 - 4s - loss: 0.0186 - accuracy: 0.9942 - val_loss: 0.0238 - val_accuracy: 0.9930 - 4s/epoch - 8ms/step
# Epoch 12/100
# 469/469 - 4s - loss: 0.0184 - accuracy: 0.9942 - val_loss: 0.0186 - val_accuracy: 0.9947 - 4s/epoch - 8ms/step
# Epoch 13/100
# 469/469 - 4s - loss: 0.0167 - accuracy: 0.9949 - val_loss: 0.0172 - val_accuracy: 0.9956 - 4s/epoch - 8ms/step
# Epoch 14/100
# 469/469 - 4s - loss: 0.0158 - accuracy: 0.9952 - val_loss: 0.0175 - val_accuracy: 0.9944 - 4s/epoch - 8ms/step
# Epoch 15/100
# 469/469 - 4s - loss: 0.0167 - accuracy: 0.9943 - val_loss: 0.0174 - val_accuracy: 0.9955 - 4s/epoch - 8ms/step
# Epoch 16/100
# 469/469 - 4s - loss: 0.0143 - accuracy: 0.9957 - val_loss: 0.0226 - val_accuracy: 0.9938 - 4s/epoch - 8ms/step
# Epoch 17/100
# 469/469 - 4s - loss: 0.0155 - accuracy: 0.9951 - val_loss: 0.0240 - val_accuracy: 0.9938 - 4s/epoch - 8ms/step
# Epoch 18/100
# 469/469 - 4s - loss: 0.0134 - accuracy: 0.9959 - val_loss: 0.0205 - val_accuracy: 0.9943 - 4s/epoch - 8ms/step
# Epoch 19/100
# 469/469 - 4s - loss: 0.0127 - accuracy: 0.9961 - val_loss: 0.0179 - val_accuracy: 0.9952 - 4s/epoch - 8ms/step
# Epoch 20/100
# 469/469 - 4s - loss: 0.0117 - accuracy: 0.9965 - val_loss: 0.0250 - val_accuracy: 0.9945 - 4s/epoch - 8ms/step
# Epoch 21/100
# 469/469 - 4s - loss: 0.0124 - accuracy: 0.9962 - val_loss: 0.0181 - val_accuracy: 0.9935 - 4s/epoch - 8ms/step
# Epoch 22/100
# 469/469 - 4s - loss: 0.0134 - accuracy: 0.9960 - val_loss: 0.0199 - val_accuracy: 0.9950 - 4s/epoch - 8ms/step
# Epoch 23/100
# 469/469 - 4s - loss: 0.0120 - accuracy: 0.9963 - val_loss: 0.0199 - val_accuracy: 0.9953 - 4s/epoch - 8ms/step
# Epoch 24/100
# 469/469 - 4s - loss: 0.0101 - accuracy: 0.9969 - val_loss: 0.0267 - val_accuracy: 0.9934 - 4s/epoch - 8ms/step
# Epoch 25/100
# 469/469 - 4s - loss: 0.0103 - accuracy: 0.9968 - val_loss: 0.0224 - val_accuracy: 0.9952 - 4s/epoch - 8ms/step
# Epoch 26/100
# 469/469 - 4s - loss: 0.0103 - accuracy: 0.9965 - val_loss: 0.0210 - val_accuracy: 0.9947 - 4s/epoch - 8ms/step
# Epoch 27/100
# 469/469 - 4s - loss: 0.0092 - accuracy: 0.9971 - val_loss: 0.0250 - val_accuracy: 0.9944 - 4s/epoch - 8ms/step
# Epoch 28/100
# 469/469 - 4s - loss: 0.0087 - accuracy: 0.9971 - val_loss: 0.0190 - val_accuracy: 0.9956 - 4s/epoch - 8ms/step
# Epoch 29/100
# 469/469 - 4s - loss: 0.0099 - accuracy: 0.9968 - val_loss: 0.0187 - val_accuracy: 0.9957 - 4s/epoch - 8ms/step
# Epoch 30/100
# 469/469 - 4s - loss: 0.0105 - accuracy: 0.9966 - val_loss: 0.0213 - val_accuracy: 0.9943 - 4s/epoch - 8ms/step
# Epoch 31/100
# 469/469 - 4s - loss: 0.0099 - accuracy: 0.9971 - val_loss: 0.0184 - val_accuracy: 0.9956 - 4s/epoch - 8ms/step
# Epoch 32/100
# 469/469 - 4s - loss: 0.0080 - accuracy: 0.9978 - val_loss: 0.0174 - val_accuracy: 0.9946 - 4s/epoch - 8ms/step
# Epoch 33/100
# 469/469 - 4s - loss: 0.0095 - accuracy: 0.9970 - val_loss: 0.0182 - val_accuracy: 0.9950 - 4s/epoch - 8ms/step
# Epoch 34/100
# 469/469 - 4s - loss: 0.0074 - accuracy: 0.9978 - val_loss: 0.0254 - val_accuracy: 0.9944 - 4s/epoch - 8ms/step
# Epoch 35/100
# 469/469 - 4s - loss: 0.0113 - accuracy: 0.9966 - val_loss: 0.0200 - val_accuracy: 0.9950 - 4s/epoch - 8ms/step
# Epoch 36/100
# 469/469 - 4s - loss: 0.0079 - accuracy: 0.9976 - val_loss: 0.0206 - val_accuracy: 0.9964 - 4s/epoch - 8ms/step
# Epoch 37/100
# 469/469 - 4s - loss: 0.0083 - accuracy: 0.9977 - val_loss: 0.0211 - val_accuracy: 0.9955 - 4s/epoch - 8ms/step
# Epoch 38/100
# 469/469 - 4s - loss: 0.0070 - accuracy: 0.9980 - val_loss: 0.0268 - val_accuracy: 0.9953 - 4s/epoch - 8ms/step
# Epoch 39/100
# 469/469 - 4s - loss: 0.0088 - accuracy: 0.9973 - val_loss: 0.0253 - val_accuracy: 0.9948 - 4s/epoch - 8ms/step
# Epoch 40/100
# 469/469 - 4s - loss: 0.0099 - accuracy: 0.9972 - val_loss: 0.0215 - val_accuracy: 0.9952 - 4s/epoch - 8ms/step
# Epoch 41/100
# 469/469 - 4s - loss: 0.0084 - accuracy: 0.9975 - val_loss: 0.0228 - val_accuracy: 0.9947 - 4s/epoch - 8ms/step
# Epoch 42/100
# 469/469 - 4s - loss: 0.0086 - accuracy: 0.9974 - val_loss: 0.0243 - val_accuracy: 0.9946 - 4s/epoch - 8ms/step
# Epoch 43/100
# 469/469 - 4s - loss: 0.0086 - accuracy: 0.9975 - val_loss: 0.0270 - val_accuracy: 0.9945 - 4s/epoch - 8ms/step
# Epoch 44/100
# 469/469 - 4s - loss: 0.0068 - accuracy: 0.9980 - val_loss: 0.0253 - val_accuracy: 0.9942 - 4s/epoch - 8ms/step
# Epoch 45/100
# 469/469 - 4s - loss: 0.0076 - accuracy: 0.9977 - val_loss: 0.0222 - val_accuracy: 0.9955 - 4s/epoch - 8ms/step
# Epoch 46/100
# 469/469 - 4s - loss: 0.0060 - accuracy: 0.9980 - val_loss: 0.0311 - val_accuracy: 0.9938 - 4s/epoch - 8ms/step
# Epoch 47/100
# 469/469 - 4s - loss: 0.0083 - accuracy: 0.9975 - val_loss: 0.0271 - val_accuracy: 0.9948 - 4s/epoch - 8ms/step
# Epoch 48/100
# 469/469 - 4s - loss: 0.0079 - accuracy: 0.9975 - val_loss: 0.0228 - val_accuracy: 0.9949 - 4s/epoch - 8ms/step
# Epoch 49/100
# 469/469 - 4s - loss: 0.0073 - accuracy: 0.9975 - val_loss: 0.0266 - val_accuracy: 0.9952 - 4s/epoch - 8ms/step
# Epoch 50/100
# 469/469 - 4s - loss: 0.0094 - accuracy: 0.9976 - val_loss: 0.0299 - val_accuracy: 0.9946 - 4s/epoch - 8ms/step
# Epoch 51/100
# 469/469 - 4s - loss: 0.0092 - accuracy: 0.9973 - val_loss: 0.0204 - val_accuracy: 0.9951 - 4s/epoch - 8ms/step
# Epoch 52/100
# 469/469 - 4s - loss: 0.0056 - accuracy: 0.9984 - val_loss: 0.0240 - val_accuracy: 0.9951 - 4s/epoch - 8ms/step
# Epoch 53/100
# 469/469 - 4s - loss: 0.0063 - accuracy: 0.9981 - val_loss: 0.0351 - val_accuracy: 0.9940 - 4s/epoch - 8ms/step
# Epoch 54/100
# 469/469 - 4s - loss: 0.0074 - accuracy: 0.9980 - val_loss: 0.0241 - val_accuracy: 0.9951 - 4s/epoch - 8ms/step
# Epoch 55/100
# 469/469 - 4s - loss: 0.0077 - accuracy: 0.9978 - val_loss: 0.0280 - val_accuracy: 0.9956 - 4s/epoch - 8ms/step
# Epoch 56/100
# 469/469 - 4s - loss: 0.0076 - accuracy: 0.9977 - val_loss: 0.0304 - val_accuracy: 0.9942 - 4s/epoch - 8ms/step
# Epoch 57/100
# 469/469 - 4s - loss: 0.0084 - accuracy: 0.9979 - val_loss: 0.0294 - val_accuracy: 0.9943 - 4s/epoch - 8ms/step
# Epoch 58/100
# 469/469 - 4s - loss: 0.0077 - accuracy: 0.9980 - val_loss: 0.0215 - val_accuracy: 0.9952 - 4s/epoch - 8ms/step
# Epoch 59/100
# 469/469 - 4s - loss: 0.0067 - accuracy: 0.9978 - val_loss: 0.0306 - val_accuracy: 0.9953 - 4s/epoch - 8ms/step
# Epoch 60/100
# 469/469 - 4s - loss: 0.0076 - accuracy: 0.9978 - val_loss: 0.0350 - val_accuracy: 0.9948 - 4s/epoch - 8ms/step
# Epoch 61/100
# 469/469 - 4s - loss: 0.0075 - accuracy: 0.9978 - val_loss: 0.0358 - val_accuracy: 0.9941 - 4s/epoch - 8ms/step
# Epoch 62/100
# 469/469 - 4s - loss: 0.0073 - accuracy: 0.9979 - val_loss: 0.0308 - val_accuracy: 0.9948 - 4s/epoch - 8ms/step
# Epoch 63/100
# 469/469 - 4s - loss: 0.0078 - accuracy: 0.9978 - val_loss: 0.0302 - val_accuracy: 0.9949 - 4s/epoch - 8ms/step
# Epoch 64/100
# 469/469 - 4s - loss: 0.0075 - accuracy: 0.9979 - val_loss: 0.0281 - val_accuracy: 0.9953 - 4s/epoch - 8ms/step
# Epoch 65/100
# 469/469 - 4s - loss: 0.0049 - accuracy: 0.9985 - val_loss: 0.0291 - val_accuracy: 0.9949 - 4s/epoch - 8ms/step
# Epoch 66/100
# 469/469 - 4s - loss: 0.0073 - accuracy: 0.9979 - val_loss: 0.0346 - val_accuracy: 0.9941 - 4s/epoch - 8ms/step
# Epoch 67/100
# 469/469 - 4s - loss: 0.0061 - accuracy: 0.9980 - val_loss: 0.0412 - val_accuracy: 0.9941 - 4s/epoch - 8ms/step
# Epoch 68/100
# 469/469 - 4s - loss: 0.0062 - accuracy: 0.9983 - val_loss: 0.0304 - val_accuracy: 0.9948 - 4s/epoch - 8ms/step
# Epoch 69/100
# 469/469 - 4s - loss: 0.0055 - accuracy: 0.9983 - val_loss: 0.0332 - val_accuracy: 0.9946 - 4s/epoch - 8ms/step
# Epoch 70/100
# 469/469 - 4s - loss: 0.0074 - accuracy: 0.9979 - val_loss: 0.0332 - val_accuracy: 0.9955 - 4s/epoch - 8ms/step
# Epoch 71/100
# 469/469 - 4s - loss: 0.0067 - accuracy: 0.9980 - val_loss: 0.0306 - val_accuracy: 0.9947 - 4s/epoch - 8ms/step
# Epoch 72/100
# 469/469 - 4s - loss: 0.0083 - accuracy: 0.9978 - val_loss: 0.0208 - val_accuracy: 0.9959 - 4s/epoch - 8ms/step
# Epoch 73/100
# 469/469 - 4s - loss: 0.0063 - accuracy: 0.9981 - val_loss: 0.0339 - val_accuracy: 0.9948 - 4s/epoch - 8ms/step
# Epoch 74/100
# 469/469 - 4s - loss: 0.0072 - accuracy: 0.9980 - val_loss: 0.0417 - val_accuracy: 0.9937 - 4s/epoch - 8ms/step
# Epoch 75/100
# 469/469 - 4s - loss: 0.0077 - accuracy: 0.9979 - val_loss: 0.0307 - val_accuracy: 0.9955 - 4s/epoch - 8ms/step
# Epoch 76/100
# 469/469 - 4s - loss: 0.0085 - accuracy: 0.9977 - val_loss: 0.0306 - val_accuracy: 0.9949 - 4s/epoch - 8ms/step
# Epoch 77/100
# 469/469 - 4s - loss: 0.0077 - accuracy: 0.9980 - val_loss: 0.0322 - val_accuracy: 0.9951 - 4s/epoch - 8ms/step
# Epoch 78/100
# 469/469 - 4s - loss: 0.0055 - accuracy: 0.9984 - val_loss: 0.0333 - val_accuracy: 0.9949 - 4s/epoch - 8ms/step
# Epoch 79/100
# 469/469 - 4s - loss: 0.0053 - accuracy: 0.9984 - val_loss: 0.0387 - val_accuracy: 0.9940 - 4s/epoch - 8ms/step
# Epoch 80/100
# 469/469 - 4s - loss: 0.0076 - accuracy: 0.9980 - val_loss: 0.0380 - val_accuracy: 0.9944 - 4s/epoch - 8ms/step
# Epoch 81/100
# 469/469 - 4s - loss: 0.0065 - accuracy: 0.9983 - val_loss: 0.0339 - val_accuracy: 0.9947 - 4s/epoch - 8ms/step
# Epoch 82/100
# 469/469 - 4s - loss: 0.0061 - accuracy: 0.9985 - val_loss: 0.0337 - val_accuracy: 0.9946 - 4s/epoch - 8ms/step
# Epoch 83/100
# 469/469 - 4s - loss: 0.0065 - accuracy: 0.9983 - val_loss: 0.0323 - val_accuracy: 0.9950 - 4s/epoch - 8ms/step
# Epoch 84/100
# 469/469 - 4s - loss: 0.0056 - accuracy: 0.9983 - val_loss: 0.0349 - val_accuracy: 0.9952 - 4s/epoch - 8ms/step
# Epoch 85/100
# 469/469 - 4s - loss: 0.0080 - accuracy: 0.9980 - val_loss: 0.0308 - val_accuracy: 0.9946 - 4s/epoch - 8ms/step
# Epoch 86/100
# 469/469 - 4s - loss: 0.0072 - accuracy: 0.9981 - val_loss: 0.0335 - val_accuracy: 0.9954 - 4s/epoch - 8ms/step
# Epoch 87/100
# 469/469 - 4s - loss: 0.0064 - accuracy: 0.9983 - val_loss: 0.0368 - val_accuracy: 0.9949 - 4s/epoch - 8ms/step
# Epoch 88/100
# 469/469 - 4s - loss: 0.0059 - accuracy: 0.9983 - val_loss: 0.0342 - val_accuracy: 0.9946 - 4s/epoch - 8ms/step
# Epoch 89/100
# 469/469 - 4s - loss: 0.0057 - accuracy: 0.9983 - val_loss: 0.0415 - val_accuracy: 0.9940 - 4s/epoch - 8ms/step
# Epoch 90/100
# 469/469 - 4s - loss: 0.0065 - accuracy: 0.9982 - val_loss: 0.0434 - val_accuracy: 0.9944 - 4s/epoch - 8ms/step
# Epoch 91/100
# 469/469 - 4s - loss: 0.0069 - accuracy: 0.9982 - val_loss: 0.0359 - val_accuracy: 0.9952 - 4s/epoch - 8ms/step
# Epoch 92/100
# 469/469 - 4s - loss: 0.0076 - accuracy: 0.9981 - val_loss: 0.0407 - val_accuracy: 0.9939 - 4s/epoch - 8ms/step
# Epoch 93/100
# 469/469 - 4s - loss: 0.0069 - accuracy: 0.9983 - val_loss: 0.0301 - val_accuracy: 0.9951 - 4s/epoch - 8ms/step
# Epoch 94/100
# 469/469 - 4s - loss: 0.0061 - accuracy: 0.9984 - val_loss: 0.0457 - val_accuracy: 0.9951 - 4s/epoch - 8ms/step
# Epoch 95/100
# 469/469 - 4s - loss: 0.0054 - accuracy: 0.9987 - val_loss: 0.0338 - val_accuracy: 0.9955 - 4s/epoch - 8ms/step
# Epoch 96/100
# 469/469 - 4s - loss: 0.0072 - accuracy: 0.9980 - val_loss: 0.0379 - val_accuracy: 0.9949 - 4s/epoch - 8ms/step
# Epoch 97/100
# 469/469 - 4s - loss: 0.0050 - accuracy: 0.9987 - val_loss: 0.0335 - val_accuracy: 0.9950 - 4s/epoch - 8ms/step
# Epoch 98/100
# 469/469 - 4s - loss: 0.0066 - accuracy: 0.9983 - val_loss: 0.0344 - val_accuracy: 0.9947 - 4s/epoch - 8ms/step
# Epoch 99/100
# 469/469 - 4s - loss: 0.0070 - accuracy: 0.9982 - val_loss: 0.0404 - val_accuracy: 0.9944 - 4s/epoch - 8ms/step
# Epoch 100/100
# 469/469 - 4s - loss: 0.0076 - accuracy: 0.9980 - val_loss: 0.0426 - val_accuracy: 0.9938 - 4s/epoch - 8ms/step
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0426 - accuracy: 0.9938
#
# Model Test Accuracy:  99.37999844551086  %
# Program Execution Time (GPU):  364.62790727615356  seconds
